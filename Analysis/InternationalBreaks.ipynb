# %%
import pandas as pd
import os

# %%
data_folder = os.path.join(os.path.dirname(os.getcwd()), 'PastSeasonsData')
print(data_folder)
# Out:
# /home/itan/Documents/Backend/PastSeasonsData

# %%
def get_file_path(filename):
    return os.path.join(base_folder, filename)

# File names
files_2024 = ['202324_cleaned_players.csv', '202324_fixtures.csv', '202324_teams.csv']
files_2023 = ['202223_cleaned_players.csv', '202223_fixtures.csv', '202223_teams.csv']

# Load 2024 data
players_2024 = pd.read_csv(get_file_path(files_2024[0]))
fixtures_2024 = pd.read_csv(get_file_path(files_2024[1]))
teams_2024 = pd.read_csv(get_file_path(files_2024[2]))

# Load 2023 data
players_2023 = pd.read_csv(get_file_path(files_2023[0]))
fixtures_2023 = pd.read_csv(get_file_path(files_2023[1]))
teams_2023 = pd.read_csv(get_file_path(files_2023[2]))

# %%
players_2023.first_name.sort_values().head(10)
# Out:
# 143        Aaron
# 522        Aaron
# 713        Aaron
# 12         Aaron
# 288    Abdoulaye
# 78          Adam
# 163         Adam
# 400         Adam
# 638         Adam
# 157         Adam
# Name: first_name, dtype: object

# %%
# Out:
# Index(['first_name', 'second_name', 'goals_scored', 'assists', 'total_points',
#        'minutes', 'goals_conceded', 'creativity', 'influence', 'threat',
#        'bonus', 'bps', 'ict_index', 'clean_sheets', 'red_cards',
#        'yellow_cards', 'selected_by_percent', 'now_cost', 'element_type'],
#       dtype='object')

# %%
mergedgw2023 = pd.read_csv('https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/refs/heads/master/data/2023-24/gws/merged_gw.csv')

# %%
mergedgw2023
# Out:
#                          name position            team   xP  assists  bonus  \
# 0                 Femi Seriki      DEF   Sheffield Utd  0.5        0      0
# 1            Jack Hinshelwood      MID        Brighton  1.5        0      0
# 2                Jadon Sancho      MID         Man Utd  3.0        0      0
# 3      Rhys Norrington-Davies      DEF   Sheffield Utd  0.1        0      0
# 4               Vitaly Janelt      MID       Brentford  2.1        0      0
# ...                       ...      ...             ...  ...      ...    ...
# 29720             Kyle Walker      DEF        Man City  7.5        0      0
# 29721             Jacob Brown      FWD           Luton  0.0        0      0
# 29722          Vicente Guaita       GK  Crystal Palace  0.0        0      0
# 29723  Braian Ojeda Rodríguez      MID   Nott'm Forest  0.0        0      0
# 29724      Mads Bech Sørensen      DEF       Brentford  0.0        0      0
#
# ...
